# %%
# %pip install scikit-bio
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.7/11.7 MB 390.1 kB/s  0:00:32 0:00:01m eta 0:00:02
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Using cached patsy-1.0.2-py2.py3-none-any.whl.metadata (3.6 kB)
# ...
#   Using cached click-8.4.2-py3-none-any.whl.metadata (2.6 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.4/10.4 MB 708.8 kB/s  0:00:14a 0:00:010:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 556.8 kB/s  0:00:10526.6 kB/s eta 0:00:01
# ...
# Using cached patsy-1.0.2-py2.py3-none-any.whl (233 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.3/10.3 MB 2.7 MB/s  0:00:03 eta 0:00:0136m0:00:01
# Using cached click-8.4.2-py3-none-any.whl (119 kB)
# ...
#   Created wheel for biom-format: filename=biom_format-2.1.17-cp314-cp314-linux_x86_64.whl size=11889738 sha256=7b373036f3bd0c63f19ac05237dd982866a58725e3f4a59aabb2a411d06b8bd2
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from skbio.stats.ordination import pcoa

# %%
pop_structure = np.load("../data/raw/Pf8_mean_genotype_distance.npy")
# Out:
# ---------------------------------------------------------------------------
# EOFError                                  Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 pop_structure = np.load("../data/raw/Pf8_mean_genotype_distance.npy")
#
# File ~/miniforge3/envs/jp/lib/python3.14/site-packages/numpy/lib/_npyio_impl.py:463, in load(file, mmap_mode, allow_pickle, fix_imports, encoding, max_header_size)
#     461 magic = fid.read(N)
#     462 if not magic:
# --> 463     raise EOFError("No data left in file")
#     464 # If the file size is less than N, we need to make sure not
#     465 # to seek past the beginning of the file
#     466 fid.seek(-min(N, len(magic)), 1)  # back-up
#
# EOFError: No data left in file

# %%
# dermining matrix shape
print(pop_structure.shape)
